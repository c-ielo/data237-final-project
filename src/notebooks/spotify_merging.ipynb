# %%
import sys
import os

PROJECT_ROOT = os.path.abspath(os.path.join('..'))  # from notebooks/ to project root
sys.path.append(os.path.join(PROJECT_ROOT, "src", "preprocessing"))

from merge_datasets import load_and_clean_spotify_charts, process_multiple_years

# %%
BASE_DIR = os.path.join(PROJECT_ROOT, "data")
YEARS = [2019, 2020, 2021, 2022, 2023, 2024, 2025]

# Process all years
process_multiple_years(BASE_DIR, YEARS)
